# %% [markdown]
# # Import packages

# %% [markdown]
# import pandas as pd
# from datetime import datetime
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from scipy import stats
# import math
# %matplotlib inline
# pd.set_option('display.max_columns', 100)
# pd.set_option('display.max_rows', 110)
# from sklearn.preprocessing import StandardScaler
# from statsmodels.formula.api import ols
# import scipy.stats as stats
# from sklearn import linear_model

# %%
import pandas as pd
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import math
# %matplotlib inline
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 110)
from sklearn.preprocessing import StandardScaler
from statsmodels.formula.api import ols
import scipy.stats as stats
from sklearn import linear_model

# %% [markdown]
# # Import data

# %%
# imported the df and removed the first column "Unnamed: 0"
df = pd.read_csv('kc_house_data_train.csv', index_col = 0)
df2 = pd.read_csv('kc_house_data_train_2.csv', index_col = 0)
df3 = pd.read_csv('kc_house_data_train_3.csv', index_col = 0)

# %%
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      2591820310  20141006T000000   365000.0         4       2.25
# 1      7974200820  20140821T000000   865000.0         5       3.00
# 2      7701450110  20140815T000000  1038000.0         4       2.50
# 3      9522300010  20150331T000000  1490000.0         3       3.50
# 4      9510861140  20140714T000000   711000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 17285   627300195  20150303T000000   750000.0         5       2.50
# 17286  8819900270  20140520T000000   440000.0         2       1.75
# 17287  3816300095  20140514T000000   310000.0         3       1.00
# 17288   122069107  20141204T000000   427500.0         3       1.50
# 17289  6703100135  20150116T000000   348000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             2070      8893     2.0           0     0          4      8
# 1             2900      6730     1.0           0     0          5      8
# 2             3770     10893     2.0           0     2          3     11
# 3             4560     14608     2.0           0     2          3     12
# 4             2550      5376     2.0           0     0          3      9
# ...            ...       ...     ...         ...   ...        ...    ...
# 17285         3240      9960     1.0           0     1          3      8
# 17286         1300      4000     2.0           0     0          3      7
# 17287         1050      9876     1.0           0     0          3      7
# 17288         1900     43186     1.5           0     0          4      7
# 17289         1330      6768     1.0           0     0          4      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            2070              0      1986             0    98058  47.4388
# 1            1830           1070      1977             0    98115  47.6784
# 2            3770              0      1997             0    98006  47.5646
# 3            4560              0      1990             0    98034  47.6995
# 4            2550              0      2004             0    98052  47.6647
# ...           ...            ...       ...           ...      ...      ...
# 17285        2020           1220      1958             0    98008  47.5858
# 17286        1300              0      1948             0    98105  47.6687
# 17287        1050              0      1953             0    98028  47.7635
# 17288        1300            600      1971             0    98038  47.4199
# 17289        1330              0      1952             0    98155  47.7366
#
#           long  sqft_living15  sqft_lot15
# 0     -122.162           2390        7700
# 1     -122.285           2370        6283
# 2     -122.129           3710        9685
# 3     -122.228           4050       14226
# 4     -122.083           2250        4050
# ...        ...            ...         ...
# 17285 -122.112           2730       10400
# 17286 -122.288           1350        4013
# 17287 -122.262           1760        9403
# 17288 -121.990           2080      108028
# 17289 -122.319           1320        6910
#
# [17290 rows x 21 columns]

# %%
df2
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       365000.0         4       2.25         2070      8893     2.0
# 1       865000.0         5       3.00         2900      6730     1.0
# 2      1038000.0         4       2.50         3770     10893     2.0
# 3      1490000.0         3       3.50         4560     14608     2.0
# 4       711000.0         3       2.50         2550      5376     2.0
# ...          ...       ...        ...          ...       ...     ...
# 17285   750000.0         5       2.50         3240      9960     1.0
# 17286   440000.0         2       1.75         1300      4000     2.0
# 17287   310000.0         3       1.00         1050      9876     1.0
# 17288   427500.0         3       1.50         1900     43186     1.5
# 17289   348000.0         3       1.50         1330      6768     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          4      8        2070              0
# 1               0     0          5      8        1830           1070
# 2               0     2          3     11        3770              0
# 3               0     2          3     12        4560              0
# 4               0     0          3      9        2550              0
# ...           ...   ...        ...    ...         ...            ...
# 17285           0     1          3      8        2020           1220
# 17286           0     0          3      7        1300              0
# 17287           0     0          3      7        1050              0
# 17288           0     0          4      7        1300            600
# 17289           0     0          4      7        1330              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1986             0    98058  47.4388 -122.162           2390
# 1          1977             0    98115  47.6784 -122.285           2370
# 2          1997             0    98006  47.5646 -122.129           3710
# 3          1990             0    98034  47.6995 -122.228           4050
# 4          2004             0    98052  47.6647 -122.083           2250
# ...         ...           ...      ...      ...      ...            ...
# 17285      1958             0    98008  47.5858 -122.112           2730
# 17286      1948             0    98105  47.6687 -122.288           1350
# 17287      1953             0    98028  47.7635 -122.262           1760
# 17288      1971             0    98038  47.4199 -121.990           2080
# 17289      1952             0    98155  47.7366 -122.319           1320
#
#        sqft_lot15  yr_sold mnth_sold
# 0            7700     2014       Oct
# 1            6283     2014       Aug
# 2            9685     2014       Aug
# 3           14226     2015       Mar
# 4            4050     2014       Jul
# ...           ...      ...       ...
# 17285       10400     2015       Mar
# 17286        4013     2014       May
# 17287        9403     2014       May
# 17288      108028     2014       Dec
# 17289        6910     2015       Jan
#
# [17290 rows x 21 columns]

# %%
df3
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       365000.0       4.0       2.25         2070      8893     2.0
# 1       865000.0       5.0       3.00         2900      6730     1.0
# 2      1038000.0       4.0       2.50         3770     10893     2.0
# 3      1490000.0       3.0       3.50         4560     14608     2.0
# 4       711000.0       3.0       2.50         2550      5376     2.0
# ...          ...       ...        ...          ...       ...     ...
# 17285   750000.0       5.0       2.50         3240      9960     1.0
# 17286   440000.0       2.0       1.75         1300      4000     2.0
# 17287   310000.0       3.0       1.00         1050      9876     1.0
# 17288   427500.0       3.0       1.50         1900     43186     1.5
# 17289   348000.0       3.0       1.50         1330      6768     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          4      8        2070              0
# 1               0     0          5      8        1830           1070
# 2               0     2          3     11        3770              0
# 3               0     2          3     12        4560              0
# 4               0     0          3      9        2550              0
# ...           ...   ...        ...    ...         ...            ...
# 17285           0     1          3      8        2020           1220
# 17286           0     0          3      7        1300              0
# 17287           0     0          3      7        1050              0
# 17288           0     0          4      7        1300            600
# 17289           0     0          4      7        1330              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1986             0    98058  47.4388 -122.162           2390
# 1          1977             0    98115  47.6784 -122.285           2370
# 2          1997             0    98006  47.5646 -122.129           3710
# 3          1990             0    98034  47.6995 -122.228           4050
# 4          2004             0    98052  47.6647 -122.083           2250
# ...         ...           ...      ...      ...      ...            ...
# 17285      1958             0    98008  47.5858 -122.112           2730
# 17286      1948             0    98105  47.6687 -122.288           1350
# 17287      1953             0    98028  47.7635 -122.262           1760
# 17288      1971             0    98038  47.4199 -121.990           2080
# 17289      1952             0    98155  47.7366 -122.319           1320
#
#        sqft_lot15  yr_sold mnth_sold          id
# 0            7700     2014       Oct  2591820310
# 1            6283     2014       Aug  7974200820
# 2            9685     2014       Aug  7701450110
# 3           14226     2015       Mar  9522300010
# 4            4050     2014       Jul  9510861140
# ...           ...      ...       ...         ...
# 17285       10400     2015       Mar   627300195
# 17286        4013     2014       May  8819900270
# 17287        9403     2014       May  3816300095
# 17288      108028     2014       Dec   122069107
# 17289        6910     2015       Jan  6703100135
#
# [17290 rows x 22 columns]

# %% [markdown]
# # Look

# %%
# explore/clean data
df.head()
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  2591820310  20141006T000000   365000.0         4       2.25         2070
# 1  7974200820  20140821T000000   865000.0         5       3.00         2900
# 2  7701450110  20140815T000000  1038000.0         4       2.50         3770
# 3  9522300010  20150331T000000  1490000.0         3       3.50         4560
# 4  9510861140  20140714T000000   711000.0         3       2.50         2550
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      8893     2.0           0     0  ...      8        2070              0
# 1      6730     1.0           0     0  ...      8        1830           1070
# 2     10893     2.0           0     2  ...     11        3770              0
# 3     14608     2.0           0     2  ...     12        4560              0
# 4      5376     2.0           0     0  ...      9        2550              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1986             0    98058  47.4388 -122.162           2390
# 1      1977             0    98115  47.6784 -122.285           2370
# 2      1997             0    98006  47.5646 -122.129           3710
# 3      1990             0    98034  47.6995 -122.228           4050
# 4      2004             0    98052  47.6647 -122.083           2250
#
#    sqft_lot15
# 0        7700
# 1        6283
# 2        9685
# 3       14226
# 4        4050
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# # Fixing the date

# %%
df['date'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        20141006T000000
# 1        20140821T000000
# 2        20140815T000000
# 3        20150331T000000
# 4        20140714T000000
#               ...
# 17285    20150303T000000
# 17286    20140520T000000
# 17287    20140514T000000
# 17288    20141204T000000
# 17289    20150116T000000
# Name: date, Length: 17290, dtype: object>

# %%
# create a new array with only dates (uncleaned)
dates_1 = df['date'].values
# create a new list to hold the cleaned dates
dates = []
for x in dates_1:
    date = x[:8]
    dates.append(date)
# display new list an check the length is correct
len(dates)

# %%
# replace the old unclean dates column with new column and check dype
df['date'] = dates
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
# covert date oject to an integer
# df['date'] = pd.to_numeric(df['date'],errors='coerce')
# df.dtypes

# %%
xs = df.date.values
formated = []
for x in xs:
    formats = datetime(year = int(x[:4]), month = int(x[4:6]), day = int(x[6:8]))
#     add formated dates to new list
    formated.append(formats)
# formate the dates so they all have the same format
formated_month = []
formated_year = []
for x in formated:
    formats_month = x.strftime('%b')
    formats_year = x.strftime('%Y')
    formated_month.append(formats_month)
    formated_year.append(formats_year)
print(len(formated_month))
print(len(formated_year))
# Out:
# 17290
# 17290

# %%
# create new columns to hold the dates by year and month/day
df['yr_sold'] = formated_year
df['mnth_sold'] = formated_month

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# yr_sold           object
# mnth_sold         object
# dtype: object

# %%
df.head()
# Out:
#            id      date      price  bedrooms  bathrooms  sqft_living  \
# 0  2591820310  20141006   365000.0         4       2.25         2070
# 1  7974200820  20140821   865000.0         5       3.00         2900
# 2  7701450110  20140815  1038000.0         4       2.50         3770
# 3  9522300010  20150331  1490000.0         3       3.50         4560
# 4  9510861140  20140714   711000.0         3       2.50         2550
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      8893     2.0           0     0  ...              0      1986
# 1      6730     1.0           0     0  ...           1070      1977
# 2     10893     2.0           0     2  ...              0      1997
# 3     14608     2.0           0     2  ...              0      1990
# 4      5376     2.0           0     0  ...              0      2004
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0             0    98058  47.4388 -122.162           2390        7700
# 1             0    98115  47.6784 -122.285           2370        6283
# 2             0    98006  47.5646 -122.129           3710        9685
# 3             0    98034  47.6995 -122.228           4050       14226
# 4             0    98052  47.6647 -122.083           2250        4050
#
#    yr_sold  mnth_sold
# 0     2014        Oct
# 1     2014        Aug
# 2     2014        Aug
# 3     2015        Mar
# 4     2014        Jul
#
# [5 rows x 23 columns]

# %%
df2 = df.drop(columns = 'date')
df2 = df2.drop(columns = 'id')
df2
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       365000.0         4       2.25         2070      8893     2.0
# 1       865000.0         5       3.00         2900      6730     1.0
# 2      1038000.0         4       2.50         3770     10893     2.0
# 3      1490000.0         3       3.50         4560     14608     2.0
# 4       711000.0         3       2.50         2550      5376     2.0
# ...          ...       ...        ...          ...       ...     ...
# 17285   750000.0         5       2.50         3240      9960     1.0
# 17286   440000.0         2       1.75         1300      4000     2.0
# 17287   310000.0         3       1.00         1050      9876     1.0
# 17288   427500.0         3       1.50         1900     43186     1.5
# 17289   348000.0         3       1.50         1330      6768     1.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 0               0     0          4      8  ...              0      1986
# 1               0     0          5      8  ...           1070      1977
# 2               0     2          3     11  ...              0      1997
# 3               0     2          3     12  ...              0      1990
# 4               0     0          3      9  ...              0      2004
# ...           ...   ...        ...    ...  ...            ...       ...
# 17285           0     1          3      8  ...           1220      1958
# 17286           0     0          3      7  ...              0      1948
# 17287           0     0          3      7  ...              0      1953
# 17288           0     0          4      7  ...            600      1971
# 17289           0     0          4      7  ...              0      1952
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0                 0    98058  47.4388 -122.162           2390        7700
# 1                 0    98115  47.6784 -122.285           2370        6283
# 2                 0    98006  47.5646 -122.129           3710        9685
# 3                 0    98034  47.6995 -122.228           4050       14226
# 4                 0    98052  47.6647 -122.083           2250        4050
# ...             ...      ...      ...      ...            ...         ...
# 17285             0    98008  47.5858 -122.112           2730       10400
# 17286             0    98105  47.6687 -122.288           1350        4013
# 17287             0    98028  47.7635 -122.262           1760        9403
# 17288             0    98038  47.4199 -121.990           2080      108028
# 17289             0    98155  47.7366 -122.319           1320        6910
#
#        yr_sold mnth_sold
# 0         2014       Oct
# 1         2014       Aug
# 2         2014       Aug
# 3         2015       Mar
# 4         2014       Jul
# ...        ...       ...
# 17285     2015       Mar
# 17286     2014       May
# 17287     2014       May
# 17288     2014       Dec
# 17289     2015       Jan
#
# [17290 rows x 21 columns]

# %%
df2.dtypes
# Out:
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# yr_sold            int64
# mnth_sold         object
# dtype: object

# %%
df2['yr_sold'] = pd.to_numeric(df['yr_sold'], errors = 'coerce')

# %%
# saved the modified df to a new csv so I can open it in a different notebook
df2.to_csv('kc_house_data_train_2.csv')

# %% [markdown]
# # Reading each column and fixing the data

# %%
# fix outliers
df2['bedrooms'] = df2['bedrooms'].replace({11:4, 33:3})

# %%
df2[df2['bedrooms']== 0]
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 483     355000.0         0       0.00         2460      8049     2.0
# 1120   1095000.0         0       0.00         3064      4764     3.5
# 2430    265000.0         0       0.75          384    213444     1.0
# 3032    235000.0         0       0.00         1470      4800     2.0
# 3609    339950.0         0       2.50         2290      8319     2.0
# 5424    380000.0         0       0.00         1470       979     3.0
# 6409    288000.0         0       1.50         1430      1650     3.0
# 9286   1295650.0         0       0.00         4810     28008     2.0
# 10067   142000.0         0       0.00          290     20875     1.0
# 10074   240000.0         0       2.50         1810      5669     2.0
# 13989   228000.0         0       1.00          390      5900     1.0
# 15733   320000.0         0       2.50         1490      7111     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 483             0     0          3      8  ...              0      1990
# 1120            0     2          3      7  ...              0      1990
# 2430            0     0          3      4  ...              0      2003
# 3032            0     0          3      7  ...              0      1996
# 3609            0     0          3      8  ...              0      1985
# 5424            0     2          3      8  ...              0      2006
# 6409            0     0          3      7  ...              0      1999
# 9286            0     0          3     12  ...              0      1990
# 10067           0     0          1      1  ...              0      1963
# 10074           0     0          3      7  ...              0      2003
# 13989           0     0          2      4  ...              0      1953
# 15733           0     0          3      7  ...              0      1999
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 483               0    98031  47.4095 -122.168           2520        8050
# 1120              0    98102  47.6362 -122.322           2360        4000
# 2430              0    98070  47.4177 -122.491           1920      224341
# 3032              0    98065  47.5265 -121.828           1060        7200
# 3609              0    98042  47.3473 -122.151           2500        8751
# 5424              0    98133  47.7145 -122.356           1470        1399
# 6409              0    98125  47.7222 -122.290           1430        1650
# 9286              0    98053  47.6642 -122.069           4740       35061
# 10067             0    98024  47.5308 -121.888           1620       22850
# 10074             0    98038  47.3493 -122.053           1810        5685
# 13989             0    98118  47.5260 -122.261           2170        6000
# 15733             0    98065  47.5261 -121.826           1500        4675
#
#        yr_sold  mnth_sold
# 483       2015        Apr
# 1120      2014        Jun
# 2430      2014        Oct
# 3032      2014        Dec
# 3609      2014        Nov
# 5424      2015        Feb
# 6409      2014        Aug
# 9286      2014        Jun
# 10067     2014        Sep
# 10074     2014        Sep
# 13989     2014        Oct
# 15733     2015        Feb
#
# [12 rows x 21 columns]

# %%
df2['bedrooms'] = df2['bedrooms'].replace({0: df2['bedrooms'].mean()})
df2['bathrooms'] = df2['bathrooms'].replace({0: df2['bathrooms'].mean()})

# %%
df2.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  1.729000e+04  17290.000000  17290.000000  17290.000000  1.729000e+04
# mean   5.407395e+05      3.372669      2.112921   2081.464604  1.524340e+04
# std    3.733190e+05      0.905743      0.769135    920.018539  4.230462e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.720000e+02
# 25%    3.210000e+05      3.000000      1.500000   1430.000000  5.081250e+03
# 50%    4.500000e+05      3.000000      2.250000   1920.000000  7.642000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.072575e+04
# max    7.700000e+06     10.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  17290.000000  17290.000000  17290.000000  17290.000000  17290.000000
# mean       1.490312      0.007981      0.238519      3.408502      7.654425
# std        0.538909      0.088985      0.775229      0.651296      1.174718
# min        1.000000      0.000000      0.000000      1.000000      1.000000
# 25%        1.000000      0.000000      0.000000      3.000000      7.000000
# 50%        1.500000      0.000000      0.000000      3.000000      7.000000
# 75%        2.000000      0.000000      0.000000      4.000000      8.000000
# max        3.500000      1.000000      4.000000      5.000000     13.000000
#
#          sqft_above  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  17290.000000   17290.000000  17290.000000  17290.000000  17290.000000
# mean    1789.306015     292.158589   1970.792019     83.806304  98078.193175
# std      829.265107     443.151874     29.343516    400.329376     53.607949
# min      290.000000       0.000000   1900.000000      0.000000  98001.000000
# 25%     1200.000000       0.000000   1951.000000      0.000000  98033.000000
# 50%     1560.000000       0.000000   1974.000000      0.000000  98065.000000
# 75%     2214.500000     560.000000   1996.000000      0.000000  98118.000000
# max     9410.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15       yr_sold
# count  17290.000000  17290.000000   17290.000000   17290.000000  17290.000000
# mean      47.560058   -122.214258    1987.986698   12873.475824   2014.323135
# std        0.138412      0.140857     684.802635   27227.437583      0.467687
# min       47.155900   -122.519000     399.000000     659.000000   2014.000000
# 25%       47.471200   -122.329000    1490.000000    5111.250000   2014.000000
# 50%       47.571600   -122.230000    1840.000000    7622.500000   2014.000000
# 75%       47.677900   -122.126000    2360.000000   10101.750000   2015.000000
# max       47.777600   -121.315000    6210.000000  858132.000000   2015.000000

# %%
df2['bathrooms'].describe()
# Out:
# count    17290.000000
# mean         2.112921
# std          0.769135
# min          0.500000
# 25%          1.500000
# 50%          2.250000
# 75%          2.500000
# max          8.000000
# Name: bathrooms, dtype: float64

# %% [markdown]
# df2['bedrooms'] = np.where(df2['id'] == 2954400190, 4, df2['bedrooms'])

# %%
df2['id'] = df['id']

# %%
df2
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       365000.0       4.0       2.25         2070      8893     2.0
# 1       865000.0       5.0       3.00         2900      6730     1.0
# 2      1038000.0       4.0       2.50         3770     10893     2.0
# 3      1490000.0       3.0       3.50         4560     14608     2.0
# 4       711000.0       3.0       2.50         2550      5376     2.0
# ...          ...       ...        ...          ...       ...     ...
# 17285   750000.0       5.0       2.50         3240      9960     1.0
# 17286   440000.0       2.0       1.75         1300      4000     2.0
# 17287   310000.0       3.0       1.00         1050      9876     1.0
# 17288   427500.0       3.0       1.50         1900     43186     1.5
# 17289   348000.0       3.0       1.50         1330      6768     1.0
#
#        waterfront  view  condition  grade  ...  yr_built  yr_renovated  \
# 0               0     0          4      8  ...      1986             0
# 1               0     0          5      8  ...      1977             0
# 2               0     2          3     11  ...      1997             0
# 3               0     2          3     12  ...      1990             0
# 4               0     0          3      9  ...      2004             0
# ...           ...   ...        ...    ...  ...       ...           ...
# 17285           0     1          3      8  ...      1958             0
# 17286           0     0          3      7  ...      1948             0
# 17287           0     0          3      7  ...      1953             0
# 17288           0     0          4      7  ...      1971             0
# 17289           0     0          4      7  ...      1952             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15  yr_sold  \
# 0        98058  47.4388 -122.162           2390        7700     2014
# 1        98115  47.6784 -122.285           2370        6283     2014
# 2        98006  47.5646 -122.129           3710        9685     2014
# 3        98034  47.6995 -122.228           4050       14226     2015
# 4        98052  47.6647 -122.083           2250        4050     2014
# ...        ...      ...      ...            ...         ...      ...
# 17285    98008  47.5858 -122.112           2730       10400     2015
# 17286    98105  47.6687 -122.288           1350        4013     2014
# 17287    98028  47.7635 -122.262           1760        9403     2014
# 17288    98038  47.4199 -121.990           2080      108028     2014
# 17289    98155  47.7366 -122.319           1320        6910     2015
#
#        mnth_sold          id
# 0            Oct  2591820310
# 1            Aug  7974200820
# 2            Aug  7701450110
# 3            Mar  9522300010
# 4            Jul  9510861140
# ...          ...         ...
# 17285        Mar   627300195
# 17286        May  8819900270
# 17287        May  3816300095
# 17288        Dec   122069107
# 17289        Jan  6703100135
#
# [17290 rows x 22 columns]

# %%
df2.to_csv('kc_house_data_train_3.csv')

# %%
df3 = pd.read_csv('kc_house_data_train_3.csv', index_col = 0)

# %%
leave = ['id','date', 'yr_sold', 'price', 'lat', 'long', 'zipcode']
take = [x for x in df3.columns if x not in leave]
print(leave)
print(take)
# Out:
# ['id', 'date', 'yr_sold', 'price', 'lat', 'long', 'zipcode']
# ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'sqft_living15', 'sqft_lot15', 'mnth_sold']

# %%
df3[take].shape
# Out:
# (17290, 16)

# %%
fig, axes = plt.subplots (nrows=8, ncols=2, figsize=(12,40))

for i, column in enumerate(take):
    sns.scatterplot(data=df3, x=column, y='price', ax=axes[i//2, i%2])

# %%
#id 1020069017
